# %%
import tensorflow as tf
import os
import numpy as np
from tensorflow.contrib.framework.python.ops.variables import get_or_create_global_step
from inception_resnet_v2 import inception_resnet_v2, inception_resnet_v2_arg_scope
import matplotlib.image as mpimg
import matplotlib
from CNN_data_preprocess import get_label_mapping, get_files, bottle_neck_process
slim = tf.contrib.slim

# %%
checkpoint_file = './model_file/inception_resnet_v2_2016_08_30.ckpt'
label_file = './labels.txt'
train_file = './Data3_4/'
bottle_neck_file = './middle_data/bottle_neck3/'
save_model_file = './model_file/inception_resnet_v2_for3'
last_layer_file = './middle_data/last_layer3/'

# %%
def build_graph():
    images = tf.placeholder(tf.float32, shape=(None, 480, 720, 3))
    labels = tf.placeholder(tf.int32, shape=(None,))

    # restore from the inception_resnet model
    with slim.arg_scope(inception_resnet_v2_arg_scope()):
            _, end_points = inception_resnet_v2(images, num_classes = 1001, is_training = False) 

    # extract the before_logit tensor from the extracted model
    before_logit = end_points['PreLogitsFlatten']


    # define a placeholder for training from the bottle, not from the beginning.
    bottle_neck = tf.placeholder(tf.float32, shape=(None,1536))

    # now define the fine tune part of the graph
    with tf.name_scope('my_fine_tune') as scope:
    #     dropout = tf.layers.dropout(bottle_neck, rate=0.3, name='dropout')
        batch_norm1 = tf.layers.batch_normalization(bottle_neck, name='batch_norm1')
        dropout1 = tf.layers.dropout(batch_norm1, rate=0.3, name='dropout1')
        dense1 = tf.layers.dense(dropout1, 128, activation=tf.nn.relu, name='dense1')
        batch_norm2 = tf.layers.batch_normalization(dense1, name='batch_norm2')
        dropout2 = tf.layers.dropout(batch_norm2, rate = 0.3, name='dropout2')
        logits = tf.layers.dense(dropout2, 4, name='logits')

        x_entropy = tf.nn.sparse_softmax_cross_entropy_with_logits(logits=logits, labels=labels)
        loss = tf.reduce_mean(x_entropy, name='loss')
        correct = tf.nn.in_top_k(logits, labels, 1)
        accuracy = tf.reduce_mean(tf.cast(correct, tf.float32))

        # extract variables that need to be trained
        weight1, bias1 = tf.get_collection(tf.GraphKeys.TRAINABLE_VARIABLES, 'dense1')
        weight2, bias2 = tf.get_collection(tf.GraphKeys.TRAINABLE_VARIABLES, 'logits')
        variables_to_train = [weight1, weight2, bias1, bias2]

        optimizer = tf.train.AdamOptimizer()
        train_op = slim.learning.create_train_op(loss, optimizer, variables_to_train=variables_to_train)

    # defiine the name scope we don't need to restore from inception_resnet
    exclude = ['InceptionResnetV2/AuxLogits', 'InceptionResnetV2/Logits',
               'my_fine_tune/','dense1','logits','batch_norm']

    variables_to_restore = slim.get_variables_to_restore(exclude = exclude)
    saver = tf.train.Saver(variables_to_restore)
    init = tf.global_variables_initializer()
    builder = tf.saved_model.builder.SavedModelBuilder(save_model_file)

    return images, labels, before_logit, bottle_neck,batch_norm2, loss, accuracy, train_op, saver, init, builder

# %%
# extract the data before the fine tune layer
def get_bottle_neck_data(sess, before_logit, images, train_file, bottle_neck_file, label_file, hsv = False):
    id2label, label2id = get_label_mapping(label_file)
    for i in id2label:
        read_dir = train_file + i
        des_dir = bottle_neck_file + i + '/'
        os.mkdir(des_dir)
        
        files = get_files(read_dir)
        for f in files:
            img=mpimg.imread(f).reshape(1,480,720,3) / 255
            if(hsv):
                img = matplotlib.colors.rgb_to_hsv(img)
            bottle = sess.run(before_logit, feed_dict={images:img})
            np.save(des_dir + f[len(read_dir):],  bottle)
            print('save the bottle neck file ' + f)

# %%
def train_graph(sess, model_list):
    images, labels, before_logit, bottle_neck, batch_norm2, loss, accuracy, train_op, saver, init, builder = model_list
    
    sess.run(init)
    saver.restore(sess, checkpoint_file)

    # if there is no dir for the bottle data, then get the data first.
    if(os.path.isdir(bottle_neck_file) is not True):
        os.mkdir(bottle_neck_file)
        get_bottle_neck_data(sess, before_logit, images, train_file, bottle_neck_file, label_file, hsv = False)

    # get training data from bottle_neck file, and train.
    bottle_neck_processor = bottle_neck_process(bottle_neck_file, label_file) 
    for i in range(2000):
        inputs, groud_truth = bottle_neck_processor.next_batch(512)
        train_loss, train_accuracy = sess.run([train_op, accuracy], feed_dict={bottle_neck: inputs, 
                                                                             labels: groud_truth})

        if(i % 50 == 0):
            val_loss, val_accuracy = sess.run([loss, accuracy],
                                              feed_dict={bottle_neck: bottle_neck_processor.val_inputs,
                                                         labels: bottle_neck_processor.val_labels})
        
            print('####################################')
            print('the training loss after ' + str(i) + ' iterations is: ' + str(train_loss))
            print('the training accuracy after ' + str(i) + ' iterations is: ' + str(train_accuracy))
            print('the val loss after ' + str(i) + ' iterations is: ' + str(val_loss))
            print('the val accuracy after ' + str(i) + ' iterations is: ' + str(val_accuracy))
            print('-------------')
            
            for i in bottle_neck_processor.id2label:
                val_accuracy = sess.run([accuracy],
                                      feed_dict={bottle_neck: bottle_neck_processor.val_inputs_each[i],
                                                 labels: bottle_neck_processor.val_labels_each[i]})
                print(i + ': the val accuracy is: '  + str(val_accuracy))
        
#         after the training process finished, store the model to a '.pb' version file.
    builder.add_meta_graph_and_variables(sess, [tf.saved_model.tag_constants.TRAINING],
                                         signature_def_map=None, assets_collection=None)
    
    builder.save()

# %%
if __name__ == '__main__':
    config = tf.ConfigProto()
    config.allow_soft_placement = True
    with tf.Session(config=config) as sess:
        model_list = build_graph()
        train_graph(sess, model_list)
# Out:
# INFO:tensorflow:Restoring parameters from ./model_file/inception_resnet_v2_2016_08_30.ckpt
# ./middle_data/bottle_neck3/A
# 211
# the lengeh of inputs is 211
# ./middle_data/bottle_neck3/D
# 302
# the lengeh of inputs is 302
# ./middle_data/bottle_neck3/W
# 1201
# the lengeh of inputs is 1201
# ####################################
# the training loss after 0 iterations is: 1.51258
# the training accuracy after 0 iterations is: 0.148728
# the val loss after 0 iterations is: 1.00218
# the val accuracy after 0 iterations is: 0.701754
# -------------
# A: the val accuracy is: [0.0]
# D: the val accuracy is: [0.0]
# W: the val accuracy is: [1.0]
# ####################################
# the training loss after 50 iterations is: 0.595129
# the training accuracy after 50 iterations is: 0.722113
# the val loss after 50 iterations is: 0.610965
# the val accuracy after 50 iterations is: 0.739766
# -------------
# A: the val accuracy is: [0.023809524]
# D: the val accuracy is: [0.38333333]
# W: the val accuracy is: [0.95416665]
# ####################################
# the training loss after 100 iterations is: 0.53107
# the training accuracy after 100 iterations is: 0.759296
# the val loss after 100 iterations is: 0.551513
# the val accuracy after 100 iterations is: 0.780702
# -------------
# A: the val accuracy is: [0.38095239]
# D: the val accuracy is: [0.40000001]
# W: the val accuracy is: [0.94583333]
# ####################################
# the training loss after 150 iterations is: 0.462121
# the training accuracy after 150 iterations is: 0.812133
# the val loss after 150 iterations is: 0.537499
# the val accuracy after 150 iterations is: 0.798246
# -------------
# A: the val accuracy is: [0.52380955]
# D: the val accuracy is: [0.41666666]
# W: the val accuracy is: [0.94166666]
# ####################################
# the training loss after 200 iterations is: 0.410903
# the training accuracy after 200 iterations is: 0.841487
# the val loss after 200 iterations is: 0.529034
# the val accuracy after 200 iterations is: 0.798246
# -------------
# A: the val accuracy is: [0.47619048]
# D: the val accuracy is: [0.46666667]
# W: the val accuracy is: [0.9375]
# ####################################
# the training loss after 250 iterations is: 0.38852
# the training accuracy after 250 iterations is: 0.863014
# the val loss after 250 iterations is: 0.512231
# the val accuracy after 250 iterations is: 0.792398
# -------------
# A: the val accuracy is: [0.5714286]
# D: the val accuracy is: [0.46666667]
# W: the val accuracy is: [0.91250002]
# ####################################
# the training loss after 300 iterations is: 0.345417
# the training accuracy after 300 iterations is: 0.864971
# the val loss after 300 iterations is: 0.511647
# the val accuracy after 300 iterations is: 0.804094
# -------------
# A: the val accuracy is: [0.5714286]
# D: the val accuracy is: [0.5]
# W: the val accuracy is: [0.92083335]
# ####################################
# the training loss after 350 iterations is: 0.338891
# the training accuracy after 350 iterations is: 0.863014
# the val loss after 350 iterations is: 0.521581
# the val accuracy after 350 iterations is: 0.795322
# -------------
# A: the val accuracy is: [0.5714286]
# D: the val accuracy is: [0.41666666]
# W: the val accuracy is: [0.92916667]
# ####################################
# the training loss after 400 iterations is: 0.307741
# the training accuracy after 400 iterations is: 0.876712
# the val loss after 400 iterations is: 0.517848
# the val accuracy after 400 iterations is: 0.804094
# -------------
# A: the val accuracy is: [0.54761904]
# D: the val accuracy is: [0.5]
# W: the val accuracy is: [0.92500001]
# ####################################
# the training loss after 450 iterations is: 0.323858
# the training accuracy after 450 iterations is: 0.880626
# the val loss after 450 iterations is: 0.511283
# the val accuracy after 450 iterations is: 0.80117
# -------------
# A: the val accuracy is: [0.66666669]
# D: the val accuracy is: [0.56666666]
# W: the val accuracy is: [0.88333333]
# ####################################
# the training loss after 500 iterations is: 0.280727
# the training accuracy after 500 iterations is: 0.896282
# the val loss after 500 iterations is: 0.527398
# the val accuracy after 500 iterations is: 0.78655
# -------------
# A: the val accuracy is: [0.47619048]
# D: the val accuracy is: [0.5]
# W: the val accuracy is: [0.91250002]
# ####################################
# the training loss after 550 iterations is: 0.243418
# the training accuracy after 550 iterations is: 0.915851
# the val loss after 550 iterations is: 0.514526
# the val accuracy after 550 iterations is: 0.809942
# -------------
# A: the val accuracy is: [0.5714286]
# D: the val accuracy is: [0.5]
# W: the val accuracy is: [0.92916667]
# ####################################
# the training loss after 600 iterations is: 0.280955
# the training accuracy after 600 iterations is: 0.864971
# the val loss after 600 iterations is: 0.548079
# the val accuracy after 600 iterations is: 0.780702
# -------------
# A: the val accuracy is: [0.45238096]
# D: the val accuracy is: [0.41666666]
# W: the val accuracy is: [0.92916667]
# ####################################
# the training loss after 650 iterations is: 0.247272
# the training accuracy after 650 iterations is: 0.886497
# the val loss after 650 iterations is: 0.54879
# the val accuracy after 650 iterations is: 0.783626
# -------------
# A: the val accuracy is: [0.54761904]
# D: the val accuracy is: [0.34999999]
# W: the val accuracy is: [0.93333334]
# ####################################
# the training loss after 700 iterations is: 0.219846
# the training accuracy after 700 iterations is: 0.917808
# the val loss after 700 iterations is: 0.516009
# the val accuracy after 700 iterations is: 0.812865
# -------------
# A: the val accuracy is: [0.59523809]
# D: the val accuracy is: [0.56666666]
# W: the val accuracy is: [0.91250002]
# ####################################
# the training loss after 750 iterations is: 0.223452
# the training accuracy after 750 iterations is: 0.908023
# the val loss after 750 iterations is: 0.526804
# the val accuracy after 750 iterations is: 0.80117
# -------------
# A: the val accuracy is: [0.5714286]
# D: the val accuracy is: [0.5]
# W: the val accuracy is: [0.91666669]
# ####################################
# the training loss after 800 iterations is: 0.226216
# the training accuracy after 800 iterations is: 0.915851
# the val loss after 800 iterations is: 0.568943
# the val accuracy after 800 iterations is: 0.798246
# -------------
# A: the val accuracy is: [0.52380955]
# D: the val accuracy is: [0.41666666]
# W: the val accuracy is: [0.94166666]
# ####################################
# the training loss after 850 iterations is: 0.176363
# the training accuracy after 850 iterations is: 0.943249
# the val loss after 850 iterations is: 0.530206
# the val accuracy after 850 iterations is: 0.807018
# -------------
# A: the val accuracy is: [0.64285713]
# D: the val accuracy is: [0.56666666]
# W: the val accuracy is: [0.89583331]
# ####################################
# the training loss after 900 iterations is: 0.173711
# the training accuracy after 900 iterations is: 0.945205
# the val loss after 900 iterations is: 0.542931
# the val accuracy after 900 iterations is: 0.804094
# -------------
# A: the val accuracy is: [0.59523809]
# D: the val accuracy is: [0.51666665]
# W: the val accuracy is: [0.91250002]
# ####################################
# the training loss after 950 iterations is: 0.159942
# the training accuracy after 950 iterations is: 0.953033
# the val loss after 950 iterations is: 0.577891
# the val accuracy after 950 iterations is: 0.789474
# -------------
# A: the val accuracy is: [0.54761904]
# D: the val accuracy is: [0.41666666]
# W: the val accuracy is: [0.92500001]
# ####################################
# the training loss after 1000 iterations is: 0.165405
# the training accuracy after 1000 iterations is: 0.947162
# the val loss after 1000 iterations is: 0.562943
# the val accuracy after 1000 iterations is: 0.798246
# -------------
# A: the val accuracy is: [0.5714286]
# D: the val accuracy is: [0.48333332]
# W: the val accuracy is: [0.91666669]
# ####################################
# the training loss after 1050 iterations is: 0.149817
# the training accuracy after 1050 iterations is: 0.960861
# the val loss after 1050 iterations is: 0.565731
# the val accuracy after 1050 iterations is: 0.780702
# -------------
# A: the val accuracy is: [0.64285713]
# D: the val accuracy is: [0.60000002]
# W: the val accuracy is: [0.85000002]
# ####################################
# the training loss after 1100 iterations is: 0.141429
# the training accuracy after 1100 iterations is: 0.966732
# the val loss after 1100 iterations is: 0.613073
# the val accuracy after 1100 iterations is: 0.80117
# -------------
# A: the val accuracy is: [0.5]
# D: the val accuracy is: [0.43333334]
# W: the val accuracy is: [0.94583333]
# ####################################
# the training loss after 1150 iterations is: 0.126031
# the training accuracy after 1150 iterations is: 0.964775
# the val loss after 1150 iterations is: 0.633451
# the val accuracy after 1150 iterations is: 0.78655
# -------------
# A: the val accuracy is: [0.52380955]
# D: the val accuracy is: [0.38333333]
# W: the val accuracy is: [0.93333334]
# ####################################
# the training loss after 1200 iterations is: 0.145095
# the training accuracy after 1200 iterations is: 0.956947
# the val loss after 1200 iterations is: 0.636673
# the val accuracy after 1200 iterations is: 0.783626
# -------------
# A: the val accuracy is: [0.5]
# D: the val accuracy is: [0.41666666]
# W: the val accuracy is: [0.92500001]
# ####################################
# the training loss after 1250 iterations is: 0.109523
# the training accuracy after 1250 iterations is: 0.970646
# the val loss after 1250 iterations is: 0.634162
# the val accuracy after 1250 iterations is: 0.798246
# -------------
# A: the val accuracy is: [0.5]
# D: the val accuracy is: [0.5]
# W: the val accuracy is: [0.92500001]
# ####################################
# the training loss after 1300 iterations is: 0.127985
# the training accuracy after 1300 iterations is: 0.976517
# the val loss after 1300 iterations is: 0.601586
# the val accuracy after 1300 iterations is: 0.798246
# -------------
# A: the val accuracy is: [0.59523809]
# D: the val accuracy is: [0.53333336]
# W: the val accuracy is: [0.89999998]
# ####################################
# the training loss after 1350 iterations is: 0.103534
# the training accuracy after 1350 iterations is: 0.980431
# the val loss after 1350 iterations is: 0.619709
# the val accuracy after 1350 iterations is: 0.795322
# -------------
# A: the val accuracy is: [0.59523809]
# D: the val accuracy is: [0.5]
# W: the val accuracy is: [0.90416664]
# ####################################
# the training loss after 1400 iterations is: 0.0952561
# the training accuracy after 1400 iterations is: 0.984344
# the val loss after 1400 iterations is: 0.614188
# the val accuracy after 1400 iterations is: 0.792398
# -------------
# A: the val accuracy is: [0.59523809]
# D: the val accuracy is: [0.53333336]
# W: the val accuracy is: [0.89166665]
# ####################################
# the training loss after 1450 iterations is: 0.0979833
# the training accuracy after 1450 iterations is: 0.980431
# the val loss after 1450 iterations is: 0.664346
# the val accuracy after 1450 iterations is: 0.792398
# -------------
# A: the val accuracy is: [0.5714286]
# D: the val accuracy is: [0.44999999]
# W: the val accuracy is: [0.91666669]
# ####################################
# the training loss after 1500 iterations is: 0.0831074
# the training accuracy after 1500 iterations is: 0.976517
# the val loss after 1500 iterations is: 0.664132
# the val accuracy after 1500 iterations is: 0.795322
# -------------
# A: the val accuracy is: [0.54761904]
# D: the val accuracy is: [0.51666665]
# W: the val accuracy is: [0.90833336]
# ####################################
# the training loss after 1550 iterations is: 0.0909926
# the training accuracy after 1550 iterations is: 0.978474
# the val loss after 1550 iterations is: 0.687382
# the val accuracy after 1550 iterations is: 0.789474
# -------------
# A: the val accuracy is: [0.52380955]
# D: the val accuracy is: [0.46666667]
# W: the val accuracy is: [0.91666669]
# ####################################
# the training loss after 1600 iterations is: 0.0903079
# the training accuracy after 1600 iterations is: 0.990215
# the val loss after 1600 iterations is: 0.702595
# the val accuracy after 1600 iterations is: 0.792398
# -------------
# A: the val accuracy is: [0.52380955]
# D: the val accuracy is: [0.48333332]
# W: the val accuracy is: [0.91666669]
# ####################################
# the training loss after 1650 iterations is: 0.0748425
# the training accuracy after 1650 iterations is: 0.988258
# the val loss after 1650 iterations is: 0.712892
# the val accuracy after 1650 iterations is: 0.798246
# -------------
# A: the val accuracy is: [0.59523809]
# D: the val accuracy is: [0.43333334]
# W: the val accuracy is: [0.92500001]
# ####################################
# the training loss after 1700 iterations is: 0.0655665
# the training accuracy after 1700 iterations is: 0.996086
# the val loss after 1700 iterations is: 0.70979
# the val accuracy after 1700 iterations is: 0.789474
# -------------
# A: the val accuracy is: [0.54761904]
# D: the val accuracy is: [0.51666665]
# W: the val accuracy is: [0.89999998]
# ####################################
# the training loss after 1750 iterations is: 0.0609477
# the training accuracy after 1750 iterations is: 0.996086
# the val loss after 1750 iterations is: 0.702249
# the val accuracy after 1750 iterations is: 0.792398
# -------------
# A: the val accuracy is: [0.59523809]
# D: the val accuracy is: [0.51666665]
# W: the val accuracy is: [0.89583331]
# ####################################
# the training loss after 1800 iterations is: 0.0588728
# the training accuracy after 1800 iterations is: 0.992172
# the val loss after 1800 iterations is: 0.697755
# the val accuracy after 1800 iterations is: 0.798246
# -------------
# A: the val accuracy is: [0.59523809]
# D: the val accuracy is: [0.55000001]
# W: the val accuracy is: [0.89583331]
# ####################################
# the training loss after 1850 iterations is: 0.0563112
# the training accuracy after 1850 iterations is: 0.998043
# the val loss after 1850 iterations is: 0.780319
# the val accuracy after 1850 iterations is: 0.78655
# -------------
# A: the val accuracy is: [0.45238096]
# D: the val accuracy is: [0.46666667]
# W: the val accuracy is: [0.92500001]
# ####################################
# the training loss after 1900 iterations is: 0.054614
# the training accuracy after 1900 iterations is: 0.998043
# the val loss after 1900 iterations is: 0.772288
# the val accuracy after 1900 iterations is: 0.792398
# -------------
# A: the val accuracy is: [0.47619048]
# D: the val accuracy is: [0.51666665]
# W: the val accuracy is: [0.91666669]
# ####################################
# the training loss after 1950 iterations is: 0.0512638
# the training accuracy after 1950 iterations is: 1.0
# the val loss after 1950 iterations is: 0.735036
# the val accuracy after 1950 iterations is: 0.798246
# -------------
# A: the val accuracy is: [0.59523809]
# D: the val accuracy is: [0.55000001]
# W: the val accuracy is: [0.89583331]
# INFO:tensorflow:No assets to save.
# INFO:tensorflow:No assets to write.
# INFO:tensorflow:SavedModel written to: b'./model_file/inception_resnet_v2_for3/saved_model.pb'
